# %% [markdown]
# ## Heatmap
# HeatMap: A way of representing data as a matrix of values. Basically, using different colors to represent data, it gives you a general view of the numerical data. Some manipulations when working with heatmaps. Python Heatmap includes normalizing the matrices, performing cluster analysis, choosing a color palette, and permuting rows and columns to place similar values nearby

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sn

# %%
df=pd.DataFrame(np.random.random((7,7)),columns=['a','b','c','d','e','f','g'])
df
# Out:
#           a         b         c         d         e         f         g
# 0  0.394596  0.230631  0.698642  0.233326  0.050478  0.748319  0.227248
# 1  0.925893  0.982259  0.288628  0.508140  0.146826  0.447799  0.212181
# 2  0.060026  0.775563  0.733036  0.489551  0.818128  0.634447  0.696034
# 3  0.987351  0.402536  0.452481  0.593087  0.715817  0.365552  0.520748
# 4  0.030552  0.131767  0.786420  0.721308  0.417989  0.015958  0.490952
# 5  0.986606  0.897521  0.294923  0.997426  0.302474  0.359512  0.514325
# 6  0.304402  0.324091  0.480860  0.123739  0.035815  0.434588  0.798633

# %%
sn.heatmap(df)
plt.show()

# %% [markdown]
# ## Annotating your Python heatmap
# You can add an annotation to every cell of your Python heatmap.

# %%
sn.heatmap(df,annot=True,annot_kws={'size':7})

# %%
##  Removing X or Y labels
sn.heatmap(df,xticklabels=False)

# %%
#Removing the color bar
sn.heatmap(df,cbar=False)

# %%
# Choosing a color theme for your heatmap
sn.heatmap(df,cmap='Greens')

# %% [markdown]
# ## Create a Word Cloud Python
# A word cloud in Python visually represents text data. Also called a tag cloud,
# it uses different font sizes and colors to highlight the importance of each word.

# %%
from wordcloud import WordCloud

# %%
text="""Python Python Python C Java JavaScript jQuery jQuery R Python Python SQL HTML Lisp Java Ruby jQuery Python
Python Django Scala Python JavaScript jQuery"""

# %%
wordcloud=WordCloud(width=500,height=500,margin=1).generate(text)

# %%
plt.imshow(wordcloud,interpolation='bilinear')
plt.margins(x=0,y=0)
plt.axis('off')
# Out:
# (-0.5, 499.5, 499.5, -0.5)

# %% [markdown]
# ## Setting the font size
# you can set a maximum and minimum font size for your Word cloud Python

# %%
wordcloud=WordCloud(width=500,height=500,max_font_size=60, min_font_size=10,margin=1).generate(text)
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 499.5, 499.5, -0.5)

# %% [markdown]
# ## Limit the number of words

# %%
wordcloud=WordCloud(width=500,height=500,max_words=4,margin=1).generate(text)
plt.imshow(wordcloud,interpolation='bilinear')
plt.show()

# %% [markdown]
# ## Exclude some words

# %%
wordcloud=WordCloud(width=500,height=500,stopwords=['Java','Django']).generate(text)
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.margins(x=0,y=0)
plt.show()

# %% [markdown]
# ## Change the background

# %%
wordcloud=WordCloud(height=500,width=500, background_color='darkturquoise').generate(text)
plt.imshow(wordcloud,interpolation='bilinear')
plt.axis('off')
plt.margins(x=0,y=0)
plt.show()
